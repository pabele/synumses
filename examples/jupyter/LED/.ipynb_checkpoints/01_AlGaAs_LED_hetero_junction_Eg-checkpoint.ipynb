# %% [markdown]
# # Simulation of an $\mathrm{Al_{x}Ga_{1-x}As}$ LED

# %% [markdown]
# The following code loads the needed modules.

# %%
import scipy.sparse as sparse 
from scipy.sparse.linalg import spsolve

import numpy as np

import matplotlib.pyplot as plt

from synumses.one_dimension.scharfetter_gummel_bernoulli import bernoulli, jacobian, update_b, first_jacobian, first_update_b

import synumses.one_dimension.parameters as parameters

from synumses.one_dimension.functions import calc_p_density, calc_n_density, hole_current_density, electron_current_density, calc_recombination


import synumses.one_dimension.solver as solver
np.set_printoptions(threshold=np.inf)
#parameters.n = 20
print (parameters.n)
# Out:
# 400

# %% [markdown]
# The mobility, the density of states and $\varepsilon_\mathrm{r}$ depend on the Al content.<br>
# For simplicity this parameter is assumed to be constant along the whole length.<br>
# The parameter **x** is the Al content.

# %%
x = .3
if (x<0.43):
        Nc = 2.5E19*(0.063+0.083*x)**(3/2)*1E6
        mu_n=(8000 - 22000*x+ 10000*x**2)*1E-4
else:
        Nc = 2.5E19*(0.85-0.14*x)**(3/2)*1E6
        mu_n=(255+1160*x-720*x**2)*1E-4
        
Nv = 2.5E19*(0.51+0.25*x)**(3/2)*1E6
mu_p=(370-970*x+740*x**2)*1E-4


parameters.Nc = np.full(parameters.n, Nc)
parameters.Nv = np.full(parameters.n, Nv)

parameters.mu_p = np.full(parameters.n, mu_p)
parameters.mu_n = np.full(parameters.n, mu_n)

parameters.Epsilon  = np.full(parameters.n, 9.8 * parameters.Epsilon_0)

parameters.Cau = np.full(parameters.n, 0.0) #

# %% [markdown]
# Definiton of the band diagramm. <br>
# Plot the band diagramm.

# %%
# Conduction and valence band

# Semiconductor ourside the quantum well
Ec_AlGaAs1   = 2.0
Ev_AlGaAs1   = 0.0

# Quantum well
Ec_AlGaAs2 = 1.8
Ev_AlGaAs2 = 0.2


#Doping outside the quantum well

Na = -1E24
Nd = 1E24

x1 = 150E-9
x2 = 160E-9
x3 = 250E-9
x4 = 260E-9

for i in range(0, parameters.n):
    if parameters.pos_x[i] < x1:
        parameters.Ec[i] = Ec_AlGaAs1
        parameters.Ev[i] = Ev_AlGaAs1
        parameters.C[i] = Na
        
    elif parameters.pos_x[i] < x2:
        parameters.Ec[i] = (
                        Ec_AlGaAs1 
                        -
                        (Ec_AlGaAs1 - Ec_AlGaAs2)*(parameters.pos_x[i] - x1)
                        /
                        (x2 - x1)
        )
        parameters.Ev[i] = (
                        Ev_AlGaAs1
                        -
                        (Ev_AlGaAs1 - Ev_AlGaAs2)*(parameters.pos_x[i] - x1)
                        /
                        (x2 - x1)
        )
        
        
    elif parameters.pos_x[i] < x3:
        parameters.Ec[i] = Ec_AlGaAs2
        parameters.Ev[i] = Ev_AlGaAs2
        parameters.C[i]  = 0.
    elif parameters.pos_x[i] < x4:
        parameters.Ec[i] = (
                        Ec_AlGaAs2
                        +
                        (Ec_AlGaAs1 - Ec_AlGaAs2)*(parameters.pos_x[i] - x3)
                        /
                        (x4 - x3)
        )
        parameters.Ev[i] = (
                            Ev_AlGaAs2
                            +
                            (Ev_AlGaAs1 - Ev_AlGaAs2)*(parameters.pos_x[i] - x3)
                            /
                            (x4 - x3)
        )
        
    else:
        parameters.Ec[i] = Ec_AlGaAs1
        parameters.Ev[i] = Ev_AlGaAs1 
        parameters.C[i] = Nd
    
    
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Conduction and valence Band", fontsize=16)

axis.plot(1E6*parameters.pos_x, parameters.Ec, label=r'$E_\mathrm{C}$')
axis.plot(1E6*parameters.pos_x, parameters.Ev, label=r'$E_\mathrm{V}$')

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

#plt.ylim(-.4, 2.4)

axis.legend()

plt.savefig("AlGaAs_hetero_junction.png")

# %% [markdown]
# The following function calculates the potential according the doping level.

# %%
parameters.init_potential()

# %% [markdown]
# Now, we plot the potential according the doping level.

# %%
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from Doping", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

axis.plot(parameters.u[0::3])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Now, let's plot the band diagramm considering diffusion but no biasing.<br>
# One Simulation **solver.solve_no_bias()** must be performed befor simulatoins with biasing.

# %%
solver.solve_no_bias()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from doping and considering diffusion", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

axis.plot(parameters.u[0::3])

plt.show()
# Out:
# /home/pabele/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)

# %% [markdown]
# Now, let's apply a voltage of $0\,\mathrm{mV}$ ! <br>
#
# Plot the:
# * potential,
# * electron and hole density,
# * electron and hole current density, and

# %%
solver.solve_no_bias()

parameters.bernoulli_limit = 1E0

bias_point = 0.01
print("Norm of b before loop:")
print(np.linalg.norm(parameters.b))

solver.solve_bias(bias_point,0)

# Potential
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from Doping", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"$\varphi$ in $\mathrm{eV}$")

axis.plot(parameters.u[0::3], label='Potential')
plt.show()


# Quasi fermi levels of electrons and holes
#fig, axis = plt.subplots(1,1, sharey=True)
#fig.suptitle("Quasi fermi levels of holes and electrons", fontsize=16)

#axis.plot(parameters.u[1::3], label='Quasi fermi levels of hole')
#axis.plot(parameters.u[2::3], label='Quasi fermi levels of electrons')
#axis.legend()
#plt.show()



# Electron and hole density
calc_p_density()
calc_n_density()
p = parameters.p_density
n = parameters.n_density

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Density of holes and electrons", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"n in $\mathrm{m^{-3}}$")

axis.semilogy(p, label='Hole density')
axis.semilogy(n, label='Electron density')
axis.legend()
plt.show()


# Electron and hole current density 
j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of holes and electrons", fontsize=16)

plt.xlabel(r"$x$ in $\mathrm{nm}$")
plt.ylabel(r"$j$ in $\mathrm{\dfrac{A}{m^{-3}}}$")

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.legend()
plt.show()
# Out:
# Norm of b before loop:
# 4.066631748061664e-15
# Norm of b:  23296000000.018154
# Norm of x: 0.23390187827227762
# Norm of b:  341.25456634259535
# Norm of x: 0.005990112495411992
# Norm of b:  0.02004955595691889
# Norm of x: 4.8864368036661156e-05
# Norm of b:  0.00279472639734076
# Norm of x: 3.710409495750031e-09
# Norm of b:  0.0021376881235185352
# Norm of x: 9.880371163327795e-15
# Norm of b:  0.0023354066316661998
# Norm of x: 1.0628416863319583e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!

# %% [markdown]
# The total current density is composed by the hole and electron current density. <br>

# %%
solver.solve_no_bias()

pot_diff = np.divide(np.diff(parameters.u[0::3]),parameters.Ut)

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potenital Difference", fontsize=16)

axis.plot(pot_diff, label='Totoal current')

axis.legend()
plt.show()

# %%
j_total = hole_current_density() + electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Totla current density", fontsize=16)

axis.plot(j_total, label='Totoal current')

axis.legend()
plt.show()

np.mean(j_total)
# Out:
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 1.5348672866821294e-20

# %% [markdown]
# Now let's simulate a voltage sweep up to get the diode characteristic. <br>
# For the simulation to converge, the voltage must be ramped up slowly.<br>
# The bias points are printed and stored in the arrays **voltage** and **current_density**.

# %%
u_start = 0.05
u_stop  = 1.6
u_step  = 0.01
voltage = []
current_density = []

bias_points = np.linspace(u_start, u_stop, int((u_stop-u_start)/u_step + 1))
for bias_point in bias_points:

    solver.solve_bias(bias_point,0)   
    
    j = np.mean(hole_current_density() + electron_current_density())
    voltage.append(bias_point)
    current_density.append(j)
    print(bias_point, ",", j)
# Out:
# Norm of b:  116480000000.00404
# Norm of x: 1.169785598375935
# Norm of b:  1543.3689289959673
# Norm of x: 0.17138901796989048
# Norm of b:  2.1614312429415454
# Norm of x: 0.029978289879049654
# Norm of b:  0.002943464398089455
# Norm of x: 0.0015105064018425401
# Norm of b:  0.00222493952643809
# Norm of x: 4.1941663453227244e-06
# Norm of b:  0.0016995136528821125
# Norm of x: 3.791249521717795e-11
# Norm of b:  0.0015913517689847183
# Norm of x: 6.0226613729120284e-15
# Norm of b:  0.0017444438060460756
# Norm of x: 7.454197651102221e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.05 , 1.5348672866821294e-20
# Norm of b:  23296000000.00012
# Norm of x: 0.2363638553451977
# Norm of b:  11.596597270724338
# Norm of x: 0.004625391891731419
# Norm of b:  0.003258716801205434
# Norm of x: 3.652742095943611e-05
# Norm of b:  0.002770535004644932
# Norm of x: 2.8771566414196532e-09
# Norm of b:  0.002109562391191019
# Norm of x: 2.132810846277626e-14
# Norm of b:  0.002143913125464723
# Norm of x: 2.3726912741618895e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.060000000000000005 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.2372563607846114
# Norm of b:  11.331977243577125
# Norm of x: 0.004202146403876994
# Norm of b:  0.0029203061828256796
# Norm of x: 3.313809638288443e-05
# Norm of b:  0.0028250058867534842
# Norm of x: 2.7149374715544025e-09
# Norm of b:  0.0023732348603684493
# Norm of x: 1.4361259807398608e-14
# Norm of b:  0.00196679529696194
# Norm of x: 5.381793726365073e-15
# Norm of b:  0.0023505670656099077
# Norm of x: 6.9621538297188325e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.07 , 1.5348672866821294e-20
# Norm of b:  23296000000.00012
# Norm of x: 0.23812801407127734
# Norm of b:  11.068916951263574
# Norm of x: 0.0037915228397892597
# Norm of b:  0.003034098714884169
# Norm of x: 3.022110791436242e-05
# Norm of b:  0.0025919896484368756
# Norm of x: 2.661500031390514e-09
# Norm of b:  0.0022346070986844456
# Norm of x: 5.710341981160564e-15
# Norm of b:  0.0018489434610784363
# Norm of x: 1.1855438162449481e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.08 , 1.5348672866821294e-20
# Norm of b:  23296000000.000088
# Norm of x: 0.2388950724593058
# Norm of b:  10.810351718695964
# Norm of x: 0.0034406199912299534
# Norm of b:  0.0022950811979903334
# Norm of x: 2.8226559433902317e-05
# Norm of b:  0.0025913290715124243
# Norm of x: 2.806798432006009e-09
# Norm of b:  0.002005330901624942
# Norm of x: 1.4039949734669677e-14
# Norm of b:  0.002116639027273505
# Norm of x: 1.1838781571115427e-14
# Norm of b:  0.002065861695390834
# Norm of x: 9.466663749332719e-15
# Norm of b:  0.0023095148512005705
# Norm of x: 1.3711646851335971e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.09 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.23967604181421914
# Norm of b:  10.557214315757681
# Norm of x: 0.003078252523602261
# Norm of b:  0.003343395361823804
# Norm of x: 2.687639298686325e-05
# Norm of b:  0.0026248522642403523
# Norm of x: 3.2568048178212263e-09
# Norm of b:  0.002222226136267898
# Norm of x: 1.5146944899877387e-14
# Norm of b:  0.0022299483699549563
# Norm of x: 1.8147367402367653e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.1 , 1.5348672866821294e-20
# Norm of b:  23296000000.00015
# Norm of x: 0.24031057266256453
# Norm of b:  10.307845873066896
# Norm of x: 0.002800624126795505
# Norm of b:  0.003057559976844479
# Norm of x: 2.707868143227288e-05
# Norm of b:  0.002754393560995603
# Norm of x: 4.389015203364838e-09
# Norm of b:  0.002055832657124365
# Norm of x: 1.2001156759054993e-14
# Norm of b:  0.001841656944254126
# Norm of x: 1.2412831317204655e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.11 , 1.5348672866821294e-20
# Norm of b:  23296000000.000202
# Norm of x: 0.24084326098003658
# Norm of b:  10.06215726821863
# Norm of x: 0.0025813336254839926
# Norm of b:  0.002745820013129722
# Norm of x: 2.8843191222272722e-05
# Norm of b:  0.002448989437100565
# Norm of x: 6.8091475956019335e-09
# Norm of b:  0.0023433060622219904
# Norm of x: 2.6132624083832345e-14
# Norm of b:  0.0021160337141774882
# Norm of x: 1.5613621480635728e-14
# Norm of b:  0.0023681119596674757
# Norm of x: 1.1150090294615962e-14
# Norm of b:  0.0020147400460499417
# Norm of x: 6.954186143804128e-15
# Norm of b:  0.002478827314878321
# Norm of x: 1.303626851931768e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.12000000000000001 , 1.5348672866821294e-20
# Norm of b:  23295999999.999992
# Norm of x: 0.24127970307854937
# Norm of b:  9.82218310183478
# Norm of x: 0.002415285766299259
# Norm of b:  0.0031899960111183103
# Norm of x: 3.194437185882548e-05
# Norm of b:  0.002402157643501715
# Norm of x: 1.1074943025300588e-08
# Norm of b:  0.0024156958895616473
# Norm of x: 2.5899716466535826e-14
# Norm of b:  0.002022492975639113
# Norm of x: 1.5801948704910787e-14
# Norm of b:  0.002165512946769609
# Norm of x: 1.0551755950365769e-14
# Norm of b:  0.002457676689685088
# Norm of x: 1.9998964988285028e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.13 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.24163712453226877
# Norm of b:  9.584621977125378
# Norm of x: 0.002286950994059199
# Norm of b:  0.0029760713592061456
# Norm of x: 3.564106464234238e-05
# Norm of b:  0.0025814735001271232
# Norm of x: 1.6880881699563058e-08
# Norm of b:  0.0018637303278978732
# Norm of x: 1.1299548386209573e-14
# Norm of b:  0.002125604307541577
# Norm of x: 5.1562811902148e-15
# Norm of b:  0.0024062841871072493
# Norm of x: 7.547414052529603e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.14 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.24192313928164264
# Norm of b:  9.353498480999225
# Norm of x: 0.0021863280836576324
# Norm of b:  0.002784258922253497
# Norm of x: 3.896900803341818e-05
# Norm of b:  0.0029121348837970033
# Norm of x: 2.287981674774671e-08
# Norm of b:  0.0024660141789521377
# Norm of x: 2.5929086033148734e-14
# Norm of b:  0.0020929568225353363
# Norm of x: 1.7956773112540273e-14
# Norm of b:  0.0022208650403409795
# Norm of x: 1.174583879618856e-14
# Norm of b:  0.002399257060544086
# Norm of x: 2.9860881445852796e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.15000000000000002 , 1.5348672866821294e-20
# Norm of b:  23296000000.00002
# Norm of x: 0.24214431942645842
# Norm of b:  9.126635932505026
# Norm of x: 0.002104882249891002
# Norm of b:  0.002736475716290132
# Norm of x: 4.134021575475153e-05
# Norm of b:  0.0026294167594501667
# Norm of x: 2.769612718892642e-08
# Norm of b:  0.0021325836077005834
# Norm of x: 1.7047138001727014e-14
# Norm of b:  0.0021415595134474754
# Norm of x: 2.5075001186342845e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.16 , 1.5348672866821294e-20
# Norm of b:  23296000000.00002
# Norm of x: 0.24230841401018025
# Norm of b:  8.902561558428436
# Norm of x: 0.0020391689249699588
# Norm of b:  0.0031336270378432645
# Norm of x: 4.2671306126183646e-05
# Norm of b:  0.0025207760214151355
# Norm of x: 3.075946216895847e-08
# Norm of b:  0.002143405055862136
# Norm of x: 1.9895894741966242e-14
# Norm of b:  0.0020950090743050557
# Norm of x: 2.4679227036289522e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.16999999999999998 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.24243076233054037
# Norm of b:  8.682477154478253
# Norm of x: 0.0019868253258889883
# Norm of b:  0.0033777381322500992
# Norm of x: 4.3195760859795966e-05
# Norm of b:  0.0027430599461365566
# Norm of x: 3.228360147798433e-08
# Norm of b:  0.0020314446518080644
# Norm of x: 2.885224235362116e-14
# Norm of b:  0.002561760115510917
# Norm of x: 6.153452695173288e-15
# Norm of b:  0.002303983998227946
# Norm of x: 1.3968150670361386e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.18 , 1.5348672866821294e-20
# Norm of b:  23296000000.000084
# Norm of x: 0.24252564296676074
# Norm of b:  8.46818744720628
# Norm of x: 0.0019459557287480704
# Norm of b:  0.0027586263794331803
# Norm of x: 4.3235089510579845e-05
# Norm of b:  0.0028070553414583786
# Norm of x: 3.280446490110911e-08
# Norm of b:  0.002016531450872883
# Norm of x: 2.1654352710405407e-14
# Norm of b:  0.0018367708695888533
# Norm of x: 1.4113025456762425e-14
# Norm of b:  0.0019420275937215628
# Norm of x: 1.1969184096717099e-14
# Norm of b:  0.0019592472853912244
# Norm of x: 1.6311849221236893e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.19 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2425935706178043
# Norm of b:  8.257119799684888
# Norm of x: 0.0019154207617511217
# Norm of b:  0.003177457895380091
# Norm of x: 4.30489243687773e-05
# Norm of b:  0.0030575760965279937
# Norm of x: 3.280634282437622e-08
# Norm of b:  0.002297408108853488
# Norm of x: 2.2568579392531862e-14
# Norm of b:  0.0024348828905831794
# Norm of x: 8.002513355414321e-15
# Norm of b:  0.0023133890185538407
# Norm of x: 7.879063538005786e-15
# Norm of b:  0.0020750314284525644
# Norm of x: 5.312923778109107e-15
# Norm of b:  0.0019290192314369839
# Norm of x: 1.2153210272034304e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.2 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2426397560322448
# Norm of b:  8.05022081184979
# Norm of x: 0.0018944149850725468
# Norm of b:  0.003256061511085543
# Norm of x: 4.2815784594048845e-05
# Norm of b:  0.0027722206657266398
# Norm of x: 3.262685173514823e-08
# Norm of b:  0.002450614601053176
# Norm of x: 2.4766018502493976e-14
# Norm of b:  0.0023085787441987915
# Norm of x: 9.693781968034048e-15
# Norm of b:  0.0021780630408517053
# Norm of x: 1.704343374663472e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.21000000000000002 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24267895175208656
# Norm of b:  7.848426056418859
# Norm of x: 0.0018779762733144197
# Norm of b:  0.0030641571824983494
# Norm of x: 4.256852793032851e-05
# Norm of b:  0.0023653533207424076
# Norm of x: 3.2366964197519053e-08
# Norm of b:  0.001868405622067936
# Norm of x: 2.1173144936414963e-14
# Norm of b:  0.0019482273938542728
# Norm of x: 1.0712589730965531e-14
# Norm of b:  0.0021516999808339787
# Norm of x: 5.399075278858955e-15
# Norm of b:  0.001944005630976174
# Norm of x: 1.3340162940269254e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.22000000000000003 , 1.5348672866821294e-20
# Norm of b:  23296000000.000015
# Norm of x: 0.24270223963170967
# Norm of b:  7.649417112467658
# Norm of x: 0.0018676568985500773
# Norm of b:  0.0033663320382495386
# Norm of x: 4.23846699132243e-05
# Norm of b:  0.0027481969424405514
# Norm of x: 3.216020439280542e-08
# Norm of b:  0.00239750201597309
# Norm of x: 2.965414829821999e-14
# Norm of b:  0.0026609207110845534
# Norm of x: 2.028937211619464e-14
# Norm of b:  0.0020160308588584855
# Norm of x: 1.3310771541206943e-14
# Norm of b:  0.002133267764138276
# Norm of x: 4.546900982807001e-15
# Norm of b:  0.002242856947074855
# Norm of x: 5.374747456021959e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.22999999999999998 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24272150503766268
# Norm of b:  7.455093501228934
# Norm of x: 0.0018601842617367327
# Norm of b:  0.0030785572725702056
# Norm of x: 4.223766128101507e-05
# Norm of b:  0.0023173363213317157
# Norm of x: 3.1985989567239164e-08
# Norm of b:  0.0026851565612491667
# Norm of x: 2.3108771797625105e-14
# Norm of b:  0.001871349717509605
# Norm of x: 7.401652312734463e-15
# Norm of b:  0.0021134444744561856
# Norm of x: 4.9742917966156355e-15
# Norm of b:  0.0021622446442334823
# Norm of x: 2.3043992847073535e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.24 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24273157801524795
# Norm of b:  7.264185681880784
# Norm of x: 0.0018558734684330123
# Norm of b:  0.0028965793309045137
# Norm of x: 4.2142443992953606e-05
# Norm of b:  0.0024003305576478498
# Norm of x: 3.187205518733577e-08
# Norm of b:  0.0019081383029799772
# Norm of x: 2.957989925994162e-14
# Norm of b:  0.0023449754518880994
# Norm of x: 2.97715322076642e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.25 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24274380412109653
# Norm of b:  7.0778696723219126
# Norm of x: 0.0018519852983302542
# Norm of b:  0.003531976598236331
# Norm of x: 4.206005321409117e-05
# Norm of b:  0.0031124310513386965
# Norm of x: 3.177000830762438e-08
# Norm of b:  0.0020922454547919237
# Norm of x: 2.202460119272496e-14
# Norm of b:  0.002166164213304113
# Norm of x: 6.087599562418454e-15
# Norm of b:  0.002288300401667377
# Norm of x: 9.57551426992432e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.26 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24275015398079913
# Norm of b:  6.894480799480732
# Norm of x: 0.0018499851839229597
# Norm of b:  0.0033260009470488165
# Norm of x: 4.201183725261262e-05
# Norm of b:  0.002631810629828455
# Norm of x: 3.1710731461434865e-08
# Norm of b:  0.0023633549656071366
# Norm of x: 2.7943776131900286e-14
# Norm of b:  0.0021351897638073403
# Norm of x: 1.9652096464713127e-14
# Norm of b:  0.0024883935579270208
# Norm of x: 1.5166843422726016e-14
# Norm of b:  0.0024657270934285054
# Norm of x: 9.305507425681512e-15
# Norm of b:  0.0025228177915823193
# Norm of x: 5.4660396092276035e-15
# Norm of b:  0.002253867524009012
# Norm of x: 9.817946336895299e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.27 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24275881535218405
# Norm of b:  6.715915332630003
# Norm of x: 0.001847818164655168
# Norm of b:  0.0031034921985662552
# Norm of x: 4.19662629414319e-05
# Norm of b:  0.002577323662745424
# Norm of x: 3.1653052375288756e-08
# Norm of b:  0.0021465787350092628
# Norm of x: 2.3505250400987413e-14
# Norm of b:  0.0024841814826695374
# Norm of x: 1.7934800739111464e-14
# Norm of b:  0.002413842380456079
# Norm of x: 2.419614582157295e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.28 , 1.5348672866821294e-20
# Norm of b:  23296000000.000015
# Norm of x: 0.24276147277043478
# Norm of b:  6.539996209374801
# Norm of x: 0.0018474833823140674
# Norm of b:  0.0034071985624143735
# Norm of x: 4.1951945419963574e-05
# Norm of b:  0.002354632323774487
# Norm of x: 3.163617140743794e-08
# Norm of b:  0.002128099469389697
# Norm of x: 2.1256319141659277e-14
# Norm of b:  0.0023402020394492195
# Norm of x: 2.0681916286124895e-14
# Norm of b:  0.0022300501270522285
# Norm of x: 2.867866470446839e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.29 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2427695896057018
# Norm of b:  6.3696358025267505
# Norm of x: 0.0018458629702612557
# Norm of b:  0.0029468402134097834
# Norm of x: 4.192120160703992e-05
# Norm of b:  0.002228460063153692
# Norm of x: 3.1596413589831846e-08
# Norm of b:  0.0023116217699079996
# Norm of x: 2.6302394149069787e-14
# Norm of b:  0.002395997144867195
# Norm of x: 7.584506543033767e-15
# Norm of b:  0.0020301105058014484
# Norm of x: 1.2416081458117253e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.3 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2427715995669995
# Norm of b:  6.202264205157263
# Norm of x: 0.0018460151440286077
# Norm of b:  0.002951297284658593
# Norm of x: 4.191942146577498e-05
# Norm of b:  0.002626442164363596
# Norm of x: 3.1595079919154614e-08
# Norm of b:  0.001971461060195475
# Norm of x: 2.0679218594810685e-14
# Norm of b:  0.0016484271104186812
# Norm of x: 1.2426499734132873e-14
# Norm of b:  0.002270319827710551
# Norm of x: 9.794803989551566e-15
# Norm of b:  0.002474116994158684
# Norm of x: 1.855535313716638e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.31 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24277770849327474
# Norm of b:  6.037506761267587
# Norm of x: 0.0018452367785951524
# Norm of b:  0.0027173690104724444
# Norm of x: 4.1904625667784506e-05
# Norm of b:  0.0028765396270695343
# Norm of x: 3.1575907216403866e-08
# Norm of b:  0.0021094173562370656
# Norm of x: 2.2294438883845266e-14
# Norm of b:  0.0021840880952175537
# Norm of x: 1.1597220067784839e-14
# Norm of b:  0.002170203185294409
# Norm of x: 1.0098138853723117e-14
# Norm of b:  0.0020981592502022036
# Norm of x: 2.1267111368356037e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.32 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2427824564845689
# Norm of b:  5.878188074591446
# Norm of x: 0.0018445872479699325
# Norm of b:  0.0029700443387230815
# Norm of x: 4.1892095345394955e-05
# Norm of b:  0.0026639685234533445
# Norm of x: 3.155954678699085e-08
# Norm of b:  0.0019365155043349358
# Norm of x: 2.0646551735964767e-14
# Norm of b:  0.0020913857225599362
# Norm of x: 8.2384850479894e-15
# Norm of b:  0.0021229941651719365
# Norm of x: 1.7442582911680463e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.33 , 1.5348672866821294e-20
# Norm of b:  23296000000.000015
# Norm of x: 0.24278374074270728
# Norm of b:  5.720320782726496
# Norm of x: 0.0018450163003570406
# Norm of b:  0.003628725761044593
# Norm of x: 4.18979660366226e-05
# Norm of b:  0.0029198481558831316
# Norm of x: 3.1567766889590986e-08
# Norm of b:  0.002346027133126525
# Norm of x: 2.110747845057203e-14
# Norm of b:  0.002180523011924248
# Norm of x: 8.193336703540098e-15
# Norm of b:  0.0023998925291474397
# Norm of x: 9.057557178265887e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.33999999999999997 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24278761309462388
# Norm of b:  5.567772401919295
# Norm of x: 0.0018448219685964474
# Norm of b:  0.0032584088993538977
# Norm of x: 4.1894090878785944e-05
# Norm of b:  0.0025777972820322194
# Norm of x: 3.156278642285552e-08
# Norm of b:  0.0020613422650111266
# Norm of x: 1.964321295884025e-14
# Norm of b:  0.0025371767751195583
# Norm of x: 8.452477988184553e-15
# Norm of b:  0.0025162456049011607
# Norm of x: 1.1634675714198472e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.35 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24279178760741119
# Norm of b:  5.417536824278124
# Norm of x: 0.0018446886317801195
# Norm of b:  0.003000021064622398
# Norm of x: 4.189144613646262e-05
# Norm of b:  0.002802294542598866
# Norm of x: 3.1559394126727165e-08
# Norm of b:  0.0022345468130358756
# Norm of x: 2.5082244385587687e-14
# Norm of b:  0.0019288945435744077
# Norm of x: 1.661082870984775e-14
# Norm of b:  0.0021093750977278724
# Norm of x: 1.4095226436686842e-14
# Norm of b:  0.0019863882587019565
# Norm of x: 4.458601943798741e-15
# Norm of b:  0.0023138531031087145
# Norm of x: 1.1433031964816912e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.36 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24279486130912808
# Norm of b:  5.271240382490227
# Norm of x: 0.0018445906910815838
# Norm of b:  0.002389835717209986
# Norm of x: 4.188948287491771e-05
# Norm of b:  0.002676031210368564
# Norm of x: 3.1556865149915206e-08
# Norm of b:  0.0021479455845892412
# Norm of x: 2.3504215621971792e-14
# Norm of b:  0.0017519367537960477
# Norm of x: 1.0922401506433966e-14
# Norm of b:  0.001450531770022723
# Norm of x: 6.517836712908761e-15
# Norm of b:  0.0017214612555429881
# Norm of x: 1.0473390743706477e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.37 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24280057808841898
# Norm of b:  5.1284257521879555
# Norm of x: 0.0018439762197537926
# Norm of b:  0.0030072432608662506
# Norm of x: 4.187898798414075e-05
# Norm of b:  0.002692296373400598
# Norm of x: 3.154283181346961e-08
# Norm of b:  0.0021161189756834934
# Norm of x: 2.05399318813722e-14
# Norm of b:  0.002258700219616788
# Norm of x: 1.1876291758654646e-14
# Norm of b:  0.0028230589419293785
# Norm of x: 1.4087344844060769e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.38 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2428010736928825
# Norm of b:  4.988174226858608
# Norm of x: 0.0018446572016692531
# Norm of b:  0.002970402043746135
# Norm of x: 4.189009960907098e-05
# Norm of b:  0.0026317876810305514
# Norm of x: 3.155782837523008e-08
# Norm of b:  0.002228113757864718
# Norm of x: 2.0739337392702517e-14
# Norm of b:  0.0023190425632794495
# Norm of x: 5.694550987757884e-15
# Norm of b:  0.002394271795664546
# Norm of x: 1.266511272236135e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.39 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24280273629696375
# Norm of b:  4.8514760116260565
# Norm of x: 0.001844959877800922
# Norm of b:  0.0031549062616102494
# Norm of x: 4.189412363347934e-05
# Norm of b:  0.0027991032037965493
# Norm of x: 3.1563279333144506e-08
# Norm of b:  0.0022440641578642304
# Norm of x: 1.9299104441837412e-14
# Norm of b:  0.0025049744905211993
# Norm of x: 5.766356627979564e-15
# Norm of b:  0.0021446474375132383
# Norm of x: 8.158096885099738e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.4 , 1.5348672866821294e-20
# Norm of b:  23296000000.000015
# Norm of x: 0.24280893558144717
# Norm of b:  4.718314417681061
# Norm of x: 0.0018443849439246723
# Norm of b:  0.0032291429970542195
# Norm of x: 4.1885677079542806e-05
# Norm of b:  0.0027319206317792553
# Norm of x: 3.155195963610052e-08
# Norm of b:  0.0022112779427162373
# Norm of x: 2.6046995640793438e-14
# Norm of b:  0.0019131089072271096
# Norm of x: 2.195099802796239e-14
# Norm of b:  0.0020589076932239552
# Norm of x: 9.981578333147721e-15
# Norm of b:  0.0023580193576280568
# Norm of x: 7.709826944725219e-15
# Norm of b:  0.0021236220075157605
# Norm of x: 1.8477747887847325e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.41 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.24280948641825642
# Norm of b:  4.587373618524248
# Norm of x: 0.0018451723796646152
# Norm of b:  0.0035716168071296445
# Norm of x: 4.189743653972114e-05
# Norm of b:  0.002936974712745347
# Norm of x: 3.156779617606266e-08
# Norm of b:  0.002273217445042541
# Norm of x: 1.9786952811477932e-14
# Norm of b:  0.0018651982393922608
# Norm of x: 1.5492632648580284e-14
# Norm of b:  0.0021581573210777655
# Norm of x: 1.0164177505133694e-14
# Norm of b:  0.0021685893786466824
# Norm of x: 4.6197773579772344e-15
# Norm of b:  0.0022191987098512003
# Norm of x: 9.354562807008988e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.42 , 1.5348672866821294e-20
# Norm of b:  23296000000.000137
# Norm of x: 0.2428152292807574
# Norm of b:  4.460993998592133
# Norm of x: 0.0018445822077605813
# Norm of b:  0.003613626239718814
# Norm of x: 4.1888802422659815e-05
# Norm of b:  0.003048870247818432
# Norm of x: 3.1556212738099616e-08
# Norm of b:  0.002235579348353153
# Norm of x: 2.3517868805296727e-14
# Norm of b:  0.0019712103582319664
# Norm of x: 1.2017485134462203e-14
# Norm of b:  0.002240883376168455
# Norm of x: 5.804433755643336e-15
# Norm of b:  0.0020700005248886003
# Norm of x: 9.468023530637406e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.43 , 1.5348672866821294e-20
# Norm of b:  23296000000.000122
# Norm of x: 0.2428195958113055
# Norm of b:  4.336557753126171
# Norm of x: 0.0018443908901142152
# Norm of b:  0.0030418374562131015
# Norm of x: 4.1885743982801326e-05
# Norm of b:  0.002760756218187297
# Norm of x: 3.155211867279714e-08
# Norm of b:  0.002297150182476636
# Norm of x: 2.237972199578194e-14
# Norm of b:  0.0023872286965149533
# Norm of x: 7.813351159520748e-15
# Norm of b:  0.0021615841472637063
# Norm of x: 4.452092226498795e-15
# Norm of b:  0.0022872364604289595
# Norm of x: 4.703929896370344e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.44 , 1.5348672866821294e-20
# Norm of b:  23296000000.00008
# Norm of x: 0.24282523714951837
# Norm of b:  4.21602201308693
# Norm of x: 0.0018439809785451623
# Norm of b:  0.0030103180328541913
# Norm of x: 4.1878394891909314e-05
# Norm of b:  0.0027593879168779935
# Norm of x: 3.1542260639592007e-08
# Norm of b:  0.002244360353901462
# Norm of x: 2.020305923657855e-14
# Norm of b:  0.001982711011672881
# Norm of x: 1.124426369324616e-14
# Norm of b:  0.002445422024443831
# Norm of x: 5.140718223726006e-15
# Norm of b:  0.0023140439594228177
# Norm of x: 1.3210286876854764e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.45 , 1.5348672866821294e-20
# Norm of b:  23296000000.00008
# Norm of x: 0.24282509886351072
# Norm of b:  4.096604407985474
# Norm of x: 0.0018448795405068999
# Norm of b:  0.0032524044733312817
# Norm of x: 4.1893501736070626e-05
# Norm of b:  0.0027304971009337107
# Norm of x: 3.156257953190901e-08
# Norm of b:  0.002607813163587829
# Norm of x: 2.1518780407406698e-14
# Norm of b:  0.002595072116922017
# Norm of x: 1.0343975986451908e-14
# Norm of b:  0.0025511779081831723
# Norm of x: 4.472376649362281e-15
# Norm of b:  0.002544522132275135
# Norm of x: 1.411246994535356e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.46 , 1.5348672866821294e-20
# Norm of b:  23295999999.999973
# Norm of x: 0.24282829524384072
# Norm of b:  3.9808361979568425
# Norm of x: 0.0018447967749159965
# Norm of b:  0.003161130206976454
# Norm of x: 4.189213312786744e-05
# Norm of b:  0.0026382841221742432
# Norm of x: 3.156074900204615e-08
# Norm of b:  0.0023997554788397946
# Norm of x: 1.9585675067539678e-14
# Norm of b:  0.0020169820224386612
# Norm of x: 6.0933700532454e-15
# Norm of b:  0.001971625729267359
# Norm of x: 1.0397554542071499e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.47 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.2428340409140804
# Norm of b:  3.868043007903261
# Norm of x: 0.0018443178615956339
# Norm of b:  0.0034101374096469498
# Norm of x: 4.1884553396571475e-05
# Norm of b:  0.0025725783823425884
# Norm of x: 3.155057826533953e-08
# Norm of b:  0.0022589963441722915
# Norm of x: 2.2120311193105156e-14
# Norm of b:  0.0026722023866108035
# Norm of x: 6.204554267797018e-15
# Norm of b:  0.0024713292365704186
# Norm of x: 1.0145985137270663e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.48 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.24283532781234876
# Norm of b:  3.758087055805545
# Norm of x: 0.0018448625346819455
# Norm of b:  0.002633131884260436
# Norm of x: 4.189321355862951e-05
# Norm of b:  0.002907399117193024
# Norm of x: 3.1562227205950805e-08
# Norm of b:  0.0023307279152383234
# Norm of x: 2.3290962018807395e-14
# Norm of b:  0.0021181974409452474
# Norm of x: 1.1684806021947969e-14
# Norm of b:  0.0019821967210953318
# Norm of x: 1.8212984920799123e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.49 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.2428458939835427
# Norm of b:  3.651312584548682
# Norm of x: 0.0018434324360780475
# Norm of b:  0.0030609367429043966
# Norm of x: 4.186688655904471e-05
# Norm of b:  0.0030781904018596417
# Norm of x: 3.1526855017902556e-08
# Norm of b:  0.001965119638366052
# Norm of x: 2.0305116832313812e-14
# Norm of b:  0.0020250400001444804
# Norm of x: 1.0219138596653987e-14
# Norm of b:  0.0019509120158076774
# Norm of x: 9.228446143001181e-15
# Norm of b:  0.001725522045529062
# Norm of x: 9.165503877630188e-15
# Norm of b:  0.0019079629918447158
# Norm of x: 1.2482333115700967e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.5 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.2428448582545499
# Norm of b:  3.5462541108631718
# Norm of x: 0.0018442016799119847
# Norm of b:  0.003496289305880481
# Norm of x: 4.188275003346781e-05
# Norm of b:  0.002997458889876554
# Norm of x: 3.1548183228064224e-08
# Norm of b:  0.0022661231870917137
# Norm of x: 2.128145167450938e-14
# Norm of b:  0.002398851327439911
# Norm of x: 7.400162821800668e-15
# Norm of b:  0.0025529317481772554
# Norm of x: 5.5549956340535765e-15
# Norm of b:  0.0022896077451859597
# Norm of x: 9.843107295498041e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.51 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.24284424386639664
# Norm of b:  3.4439354943141183
# Norm of x: 0.00184532599488658
# Norm of b:  0.003933775245990119
# Norm of x: 4.189960594214136e-05
# Norm of b:  0.0031985605944038066
# Norm of x: 3.157085312035492e-08
# Norm of b:  0.0027669578609730424
# Norm of x: 2.148857020070054e-14
# Norm of b:  0.0024011333772227367
# Norm of x: 1.3718719442354834e-14
# Norm of b:  0.002390827707523101
# Norm of x: 1.2677060974028282e-14
# Norm of b:  0.0027712960018885886
# Norm of x: 9.581869161377414e-15
# Norm of b:  0.002815200943413152
# Norm of x: 6.6258938814401304e-15
# Norm of b:  0.002963583550812809
# Norm of x: 6.0363802071039264e-15
# Norm of b:  0.002541691255711727
# Norm of x: 7.673020875598922e-15
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.52 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.2428522575985065
# Norm of b:  3.344352496988211
# Norm of x: 0.0018442651659633083
# Norm of b:  0.0030989500280266093
# Norm of x: 4.188381151894249e-05
# Norm of b:  0.0034620782307205945
# Norm of x: 3.1549633787643775e-08
# Norm of b:  0.0029054260123616863
# Norm of x: 2.0682520224314906e-14
# Norm of b:  0.0027683520013294096
# Norm of x: 5.021870676746765e-15
# Norm of b:  0.0026675724880466083
# Norm of x: 1.0886414949567685e-14
# Use the function hole_current_density() direct from scharfetter_gummel_bernoulli !!
# Use the function electron_current_density() direct from scharfetter_gummel_bernoulli !!
# 0.53 , 1.5348672866821294e-20
# Norm of b:  23296000000.00013
# Norm of x: 0.2428552974388069
# Norm of b:  3.247034184927488
# Norm of x: 0.001844471060746127
# Norm of b:  0.003234239244319035
# Norm of x: 4.188724194790945e-05
# Norm of b:  0.0031041364758304887
# Norm of x: 3.155425589688235e-08
# Norm of b:  0.002666250688803615
# Norm of x: 2.2729625996994707e-14
# Norm of b:  0.0024988872568321658
# Norm of x: 1.3435842922179083e-14
# Norm of b:  0.00275663382674255
# Norm of x: 1.127754433516551e-14
# Norm of b:  0.002484201072181749
# Norm of x: 9.505645317447604e-15

# %%
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of LED", fontsize=16)

axis.plot(voltage, current_density, label='Current density')

axis.set_xlabel(r"Voltage in $\mathrm{V}$")
axis.set_ylabel(r"Current density in $\mathrm{\dfrac{A}{m^3}}$")

axis.legend()
#plt.ylim(-1E-6,1E-6)
plt.show()

# %%
# Potential
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential with Biasing", fontsize=16)

axis.plot(parameters.u[0::3], label='Potential')
plt.show()


# Electron and hole density
calc_p_density()
calc_n_density()
p = parameters.p_density
n = parameters.n_density

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Density of holes and electrons", fontsize=16)

#plt.ylim(1E20)

axis.semilogy(p, label='Hole density')
axis.semilogy(n, label='Electron density')
axis.legend()
plt.show()


# Current densities
j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current densities", fontsize=16)

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.plot(j_n + j_p, label='Total current density')
axis.legend()
plt.show()

# Recombination
calc_recombination()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Recombination", fontsize=16)

axis.semilogy(1E6*parameters.pos_x,
                parameters.q*parameters.recombination*parameters.dx,
                label='Recombination')

axis.legend()
plt.show()
# Out:
# /home/pabele/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %% [markdown]
# Now, we start to increas recombination.

# %%
parameters.Cau = np.full(parameters.n, 1E-18)

#parameters.Cau = np.full(parameters.n, 2.3E-13*1E-8)


solver.solve_bias(bias_point,0)   

# Current densities
j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current densities", fontsize=16)

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.plot(j_n + j_p, label='Total current density')
axis.legend()
plt.show()

calc_recombination()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Recombination", fontsize=16)

axis.semilogy(1E6*parameters.pos_x,
              parameters.q*parameters.recombination*parameters.dx,
              label='Recombination')

axis.legend()
plt.show()
