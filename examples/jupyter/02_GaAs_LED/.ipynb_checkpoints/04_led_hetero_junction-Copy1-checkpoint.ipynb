# %% [markdown]
# # Simulation of an $\mathrm{Al_{x}Ga_{1-x}As}$ LED

# %% [markdown]
# The following code loads the needed modules.

# %%
import scipy.sparse as sparse 
from scipy.sparse.linalg import spsolve

import numpy as np

import matplotlib.pyplot as plt

from twoport.scharfetter_gummel_bernoulli import bernoulli, jacobian, update_b, first_jacobian, first_update_b

import twoport.parameters as parameters

from twoport.functions import calc_p_density, calc_n_density, hole_current_density, electron_current_density, calc_recombination


import twoport.solver as solver

# %% [markdown]
# The mobility, the density of states and $\varepsilon_\mathrm{r}$ depend on the Al content.<br>
# For simplicity this parameter is assumed to be constant along the whole length.<br>
# The parameter **x** is the Al content.

# %%
x = .3
if (x<0.43):
        Nc = 2.5E19*(0.063+0.083*x)**(3/2)*1E6
        mu_n=(8000 - 22000*x+ 10000*x**2)*1E-4
else:
        Nc = 2.5E19*(0.85-0.14*x)**(3/2)*1E6
        mu_n=(255+1160*x-720*x**2)*1E-4
        
Nv = 2.5E19*(0.51+0.25*x)**(3/2)*1E6
mu_p=(370-970*x+740*x**2)*1E-4


parameters.Nc = np.full(parameters.n, Nc)
parameters.Nv = np.full(parameters.n, Nv)

parameters.mu_p = np.full(parameters.n, mu_p)
parameters.mu_n = np.full(parameters.n, mu_n)

parameters.Epsilon  = np.full(parameters.n, 9.8 * parameters.Epsilon_0)

parameters.Cau = np.full(parameters.n, 1E-24) #

# %% [markdown]
# Definiton of the band diagramm. <br>
# Plot the band diagramm.

# %%
# Conduction and valence band

# Semiconductor ourside the quantum well
Ec_AlGaAs1   = 2.0
Ev_AlGaAs1   = 0.0

# Quantum well
Ec_AlGaAs2 = 1.8
Ev_AlGaAs2 = 0.2


#Doping outside the quantum well

Na = -1E24
Nd = 1E24

x1 = 150E-9
x2 = 160E-9
x3 = 250E-9
x4 = 260E-9

for i in range(0, parameters.n):
    if parameters.pos_x[i] < x1:
        parameters.Ec[i] = Ec_AlGaAs1
        parameters.Ev[i] = Ev_AlGaAs1
        parameters.C[i] = Na
        
    elif parameters.pos_x[i] < x2:
        parameters.Ec[i] = (
                        Ec_AlGaAs1 
                        -
                        (Ec_AlGaAs1 - Ec_AlGaAs2)*(parameters.pos_x[i] - x1)
                        /
                        (x2 - x1)
        )
        parameters.Ev[i] = (
                        Ev_AlGaAs1
                        -
                        (Ev_AlGaAs1 - Ev_AlGaAs2)*(parameters.pos_x[i] - x1)
                        /
                        (x2 - x1)
        )
        
        
    elif parameters.pos_x[i] < x3:
        parameters.Ec[i] = Ec_AlGaAs2
        parameters.Ev[i] = Ev_AlGaAs2
        parameters.C[i]  = 0.
    elif parameters.pos_x[i] < x4:
        parameters.Ec[i] = (
                        Ec_AlGaAs2
                        +
                        (Ec_AlGaAs1 - Ec_AlGaAs2)*(parameters.pos_x[i] - x3)
                        /
                        (x4 - x3)
        )
        parameters.Ev[i] = (
                            Ev_AlGaAs2
                            +
                            (Ev_AlGaAs1 - Ev_AlGaAs2)*(parameters.pos_x[i] - x3)
                            /
                            (x4 - x3)
        )
        
    else:
        parameters.Ec[i] = Ec_AlGaAs1
        parameters.Ev[i] = Ev_AlGaAs1 
        parameters.C[i] = Nd
    
    
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Conduction and valence Band", fontsize=16)

axis.plot(1E6*parameters.pos_x, parameters.Ec, label=r'$E_\mathrm{C}$')
axis.plot(1E6*parameters.pos_x, parameters.Ev, label=r'$E_\mathrm{V}$')

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

plt.ylim(-.4, 2.4)

axis.legend()

plt.savefig("AlGaAs_hetero_junction.png")

# %% [markdown]
# The following function calculates the potential according the doping level.

# %%
parameters.init_potential()

# %% [markdown]
# Now, we plot the potential according the doping level.

# %%
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from Doping", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

axis.plot(parameters.u[0::3])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Now, let's plot the band diagramm considering diffusion but no biasing.<br>
# One Simulation **solver.solve_no_bias()** must be performed befor simulatoins with biasing.

# %%
solver.solve_no_bias()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from doping and considering diffusion", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"Energy in $\mathrm{eV}$")

axis.plot(parameters.u[0::3])

plt.show()
# Out:
# /home/pabele/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)

# %% [markdown]
# Now, let's apply a voltage of $0\,\mathrm{mV}$ ! <br>
#
# Plot the:
# * potential,
# * electron and hole density,
# * electron and hole current density, and

# %%
bias_point = -0.0
print("Norm of b before loop:")
print(np.linalg.norm(parameters.b))

solver.solve_bias(bias_point,0)

# Potential
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential from Doping", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"$\varphi$ in $\mathrm{eV}$")

axis.plot(parameters.u[0::3], label='Potential')
plt.show()


# Quasi fermi levels of electrons and holes
#fig, axis = plt.subplots(1,1, sharey=True)
#fig.suptitle("Quasi fermi levels of holes and electrons", fontsize=16)

#axis.plot(parameters.u[1::3], label='Quasi fermi levels of hole')
#axis.plot(parameters.u[2::3], label='Quasi fermi levels of electrons')
#axis.legend()
#plt.show()



# Electron and hole density
calc_p_density()
calc_n_density()
p = parameters.p_density
n = parameters.n_density

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Density of holes and electrons", fontsize=16)

plt.xlabel(r"x in $\mathrm{nm}$")
plt.ylabel(r"n in $\mathrm{m^{-3}}$")

axis.semilogy(p, label='Hole density')
axis.semilogy(n, label='Electron density')
axis.legend()
plt.show()

# Space charge

calc_p_density()
calc_n_density()
p = parameters.p_density
n = parameters.n_density

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Space charge", fontsize=16)

plt.xlabel(r"$x$ in $\mathrm{nm}$")
plt.ylabel(r"$\varrho$ in $\mathrm{\dfrac{C}{m^3}}$")


axis.plot(parameters.q*(p-n+parameters.C), label='Space charge')

axis.legend()
plt.show()

# Electron and hole current density 
j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of holes and electrons", fontsize=16)

plt.xlabel(r"$x$ in $\mathrm{nm}$")
plt.ylabel(r"$j$ in $\mathrm{\dfrac{A}{m^{-3}}}$")

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.legend()
plt.show()
# Out:
# Norm of b before loop:
# 5.185582371590655e-15
# Norm:  0.9350325256142552
# Norm:  2.2408066673083793

# %% [markdown]
# The total current density is composed by the hole and electron current density. <br>

# %%
j_total = hole_current_density() + electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Totla current density", fontsize=16)

axis.plot(j_total, label='Totoal current')

axis.legend()
plt.show()

np.mean(j_total)
# Out:
# -9700238076.945124

# %% [markdown]
# Now let's simulate a voltage sweep up to get the diode characteristic. <br>
# For the simulation to converge, the voltage must be ramped up slowly.<br>
# The bias points are printed and stored in the arrays **voltage** and **current_density**.

# %%
u_start = 0.0
u_stop  = 1.8
u_step  = 0.05

voltage = []
current_density = []

bias_points = np.linspace(u_start, u_stop, int((u_stop-u_start)/u_step + 1))
for bias_point in bias_points:

    solver.solve_bias(bias_point,0)   
    
    j = np.mean(hole_current_density() + electron_current_density())
    voltage.append(bias_point)
    current_density.append(j)
    print(bias_point, ",", j)
# Out:
# Norm:  2.905205962458916
# Norm:  1.196379466108542
# Norm:  1.6878635071758419
# 0.0 , -9700238076.941936
# Norm:  116480000000.00047
# Norm:  2.9662846920092685e+31
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:564: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+0)+0]  = -( parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i+1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx - parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nv[i-1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2* ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:572: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+1)+0]  = -( parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nv[i+1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:556: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i-1)+0]  = -( -parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i-1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:596: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+1)+1]  = -( -parameters.Nv[i+1]*parameters.mu_p[i]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:640: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+0)+0]  = -( -parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nc[i+1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx + parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nc[i-1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters. ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:648: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+1)+0]  = -( -parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nc[i+1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:588: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+0)+1]  = -( parameters.Cau[i]*parameters.Nc[i+0]*parameters.Nv[i+0]*parameters.dx*parameters.q**2*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB) + parameters.Nv[i+0]*parameters.mu_p[i]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.mu_p[i]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+0)+2]  = -( -parameters.Cau[i]*parameters.Nc[i+0]*parameters.Nv[i+0]*parameters.dx*parameters.q**2*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:632: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i-1)+0]  = -( parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nc[i-1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:664: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+0)+1]  = -( -parameters.Cau[i]*parameters.Nc[i+0]*parameters.Nv[i+0]*parameters.dx*parameters.q**2*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:688: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+0)+2]  = -( parameters.Cau[i]*parameters.Nc[i+0]*parameters.Nv[i+0]*parameters.dx*parameters.q**2*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB) + parameters.Nc[i+0]*parameters.mu_n[i]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.mu_n[i]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:580: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i-1)+1]  = -( -parameters.Nv[i-1]*parameters.mu_p[i]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:696: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+1)+2]  = -( -parameters.Nc[i+1]*parameters.mu_n[i]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:564: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+1,3*(i+0)+0]  = -( parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i+1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx - parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nv[i-1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2* ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:572: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+1,3*(i+1)+0]  = -( parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nv[i+1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:640: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+2,3*(i+0)+0]  = -( -parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nc[i+1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx + parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nc[i-1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters. ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:648: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+2,3*(i+1)+0]  = -( -parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nc[i+1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:556: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+1,3*(i-1)+0]  = -( -parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i-1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:632: RuntimeWarning: overflow encountered in double_scalars
#   parameters.A[3*i+2,3*(i-1)+0]  = -( parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) + parameters.Nc[i-1]*parameters.q*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i-1]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:680: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i-1)+2]  = -( -parameters.Nc[i-1]*parameters.mu_n[i]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:365: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i-1)+0]  = -( -parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i-1]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i-1]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:373: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+1,3*(i+0)+0]  = -( parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(1.0*parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + Ub + 1.0*parameters.Ev[i+0])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])*np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + Ub + 1.0*parameters.Ev[i+0])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)**2) - parameters.Nv[i+0]*parameters.q**2*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])*np.exp(parameters.q*(1.0*parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q**2*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])*np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB))*np.exp(parameters.q*(1.0*parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T**2*parameters.kB**2*(np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)**2))/parameters.dx - parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.e ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:390: RuntimeWarning: invalid value encountered in double_scalars
# ...
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:454: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i-1)+2]  = -( -parameters.Nc[i-1]*parameters.mu_n[i]*parameters.q**2*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:462: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.A[3*i+2,3*(i+0)+2]  = -( parameters.Cau[i]*parameters.Nc[i+0]*parameters.Nv[i+0]*parameters.dx*parameters.q**2*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB) + parameters.Nc[i+0]*parameters.mu_n[i]*parameters.q**2*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])*np.exp(parameters.q*(-1.0*parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i+0]*parameters.mu_n[i]*parameters.q**2*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.dx*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) )
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+1] =  parameters.T*parameters.kB*parameters.mu_p[i]*(parameters.Nv[i+0]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nv[i+1]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i+1] - parameters.u[3*(i+1)+0] + parameters.u[3*(i+1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx - parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i-1]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx + parameters.dx*parameters.q*(parameters.Cau[i]*(-parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.Ev[i+0])/(parameters.T*parameters.kB)) + parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))) - parameters.generation[i])
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:112: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+2] =  -parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+1]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i+1] + parameters.u[3*(i+1)+0] - parameters.u[3*(i+1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx + parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx - parameters.dx*parameters.q*(parameters.Cau[i]*(-parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.Ev[i+0])/(parameters.T*parameters.kB)) + parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))) - parameters.generation[i])
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+0] =  -2*parameters.u[(3*i)+0] + parameters.u[3*(i+1)+0] + parameters.u[3*(i-1)+0] + parameters.dx**2*parameters.q*(parameters.C[i] - parameters.Nc[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB)) + parameters.Nv[i+0]*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB)))/parameters.Epsilon[i]
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:68: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+0] =  ( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - 2*parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0] + parameters.dx**2*parameters.q*(parameters.C[i] - parameters.Nc[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB)) + parameters.Nv[i+0]*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB)))/parameters.Epsilon[i]
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+1] =  parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])*np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + Ub + 1.0*parameters.Ev[i+0])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i+0]*parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])*np.exp(parameters.q*(1.0*parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx - parameters.T*parameters.kB*parameters.mu_p[i]*(-parameters.Nv[i+0]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nv[i-1]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(0.5*parameters.Ev[i+0] + 0.5*parameters.Ev[i-1] - parameters.u[3*(i-1)+0] + parameters.u[3*(i-1)+1])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx + parameters.dx*parameters.q*(parameters.Cau[i]*(-parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.Ev[i+0])/(parameters.T*parameters.kB)) + parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))) - parameters.generation[i])
# /home/pabele/Programming/python/semiconductor/twoport/scharfetter_gummel_bernoulli.py:84: RuntimeWarning: invalid value encountered in double_scalars
#   parameters.b[3*i+2] =  -parameters.T*parameters.kB*parameters.mu_n[i]*(parameters.Nc[i+0]*parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])*np.exp(parameters.q*(-1.0*parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) + parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)) - parameters.Nc[i+0]*parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])*np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - Ub - 1.0*parameters.Ec[i+0])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(( ohm_potential(parameters.C[parameters.n-1], parameters.Ec[parameters.n-1], parameters.Ev[parameters.n-1], parameters.Nc[parameters.n-1], parameters.Nv[parameters.n-1]) + Ub) - parameters.u[(3*i)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx + parameters.T*parameters.kB*parameters.mu_n[i]*(-parameters.Nc[i+0]*parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(parameters.u[(3*i)+0] - parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)) + parameters.Nc[i-1]*parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])*np.exp(parameters.q*(-0.5*parameters.Ec[i+0] - 0.5*parameters.Ec[i-1] + parameters.u[3*(i-1)+0] - parameters.u[3*(i-1)+2])/(parameters.T*parameters.kB))/(parameters.T*parameters.kB*(np.exp(parameters.q*(-parameters.u[(3*i)+0] + parameters.u[3*(i-1)+0])/(parameters.T*parameters.kB)) - 1)))/parameters.dx - parameters.dx*parameters.q*(parameters.Cau[i]*(-parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.Ev[i+0])/(parameters.T*parameters.kB)) + parameters.Nc[i+0]*parameters.Nv[i+0]*np.exp(parameters.q*(-parameters.Ec[i+0] + parameters.u[(3*i)+0] - parameters.u[(3*i)+2])/(parameters.T*parameters.kB))*np.exp(parameters.q*(parameters.Ev[i+0] - parameters.u[(3*i)+0] + parameters.u[(3*i)+1])/(parameters.T*parameters.kB))) - parameters.generation[i])
# /home/pabele/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:192: MatrixRankWarning: Matrix is exactly singular
#   warn("Matrix is exactly singular", MatrixRankWarning)
# Norm:  nan
# norm is nan
# 0.05 , nan
# Norm:  nan
# norm is nan
# 0.1 , nan
# Norm:  nan
# norm is nan
# 0.15000000000000002 , nan
# Norm:  nan
# norm is nan
# 0.2 , nan
# Norm:  nan
# norm is nan
# 0.25 , nan
# Norm:  nan
# norm is nan
# 0.30000000000000004 , nan
# Norm:  nan
# norm is nan
# 0.35000000000000003 , nan
# Norm:  nan
# norm is nan
# 0.4 , nan
# Norm:  nan
# norm is nan
# 0.45 , nan
# Norm:  nan
# norm is nan
# 0.5 , nan
# Norm:  nan
# norm is nan
# 0.55 , nan
# Norm:  nan
# norm is nan
# 0.6000000000000001 , nan
# Norm:  nan
# norm is nan
# 0.65 , nan
# Norm:  nan
# norm is nan
# 0.7000000000000001 , nan
# Norm:  nan
# norm is nan
# 0.75 , nan
# Norm:  nan
# norm is nan
# 0.8 , nan
# Norm:  nan
# norm is nan
# 0.8500000000000001 , nan
# Norm:  nan
# norm is nan
# 0.9 , nan
# Norm:  nan
# norm is nan
# 0.9500000000000001 , nan
# Norm:  nan
# norm is nan
# 1.0 , nan
# Norm:  nan
# norm is nan
# 1.05 , nan
# Norm:  nan
# norm is nan
# 1.1 , nan
# Norm:  nan
# norm is nan
# 1.1500000000000001 , nan
# Norm:  nan
# norm is nan
# 1.2000000000000002 , nan
# Norm:  nan
# norm is nan
# 1.25 , nan
# Norm:  nan
# norm is nan
# 1.3 , nan
# Norm:  nan
# norm is nan
# 1.35 , nan
# Norm:  nan
# norm is nan
# 1.4000000000000001 , nan
# Norm:  nan
# norm is nan
# 1.4500000000000002 , nan
# Norm:  nan
# norm is nan
# 1.5 , nan
# Norm:  nan
# norm is nan
# 1.55 , nan
# Norm:  nan
# norm is nan
# 1.6 , nan
# Norm:  nan
# norm is nan
# 1.6500000000000001 , nan
# Norm:  nan
# norm is nan
# 1.7000000000000002 , nan
# Norm:  nan
# norm is nan
# 1.75 , nan
# Norm:  nan
# norm is nan
# 1.8 , nan

# %%
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of LED", fontsize=16)

axis.plot(voltage, current_density, label='Current density')

axis.set_xlabel(r"Voltage in $\mathrm{V}$")
axis.set_ylabel(r"Current density in $\mathrm{\dfrac{A}{m^3}}$")

axis.legend()
#plt.ylim(-1E-6,1E-6)
plt.show()

# %%
# Potential
fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Potential with Biasing", fontsize=16)

axis.plot(parameters.u[0::3], label='Potential')
plt.show()


# Electron and hole density
calc_p_density()
calc_n_density()
p = parameters.p_density
n = parameters.n_density

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Density of holes and electrons", fontsize=16)

#plt.ylim(1E20)

axis.semilogy(p, label='Hole density')
axis.semilogy(n, label='Electron density')
axis.legend()
plt.show()


# Electron and hole current density 
j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of holes and electrons", fontsize=16)

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.legend()
plt.show()

# Recombination
calc_recombination()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Recombination", fontsize=16)

axis.semilogy(1E6*parameters.pos_x,
                parameters.q*parameters.recombination*parameters.dx,
                label='Recombination')

axis.legend()
plt.show()

# %% [markdown]
# Now, we start to increas recombination.

# %%
parameters.Cau = np.full(parameters.n, 2.3E-13*1E-8)

#parameters.Cau = np.full(parameters.n, 2.3E-13*1E-8)


solver.solve_bias(bias_point,0)   


# Electron and hole current density 

j_p =     hole_current_density()
j_n = electron_current_density()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Current density of holes and electrons", fontsize=16)

axis.plot(j_p, label='Hole current density')
axis.plot(j_n, label='Electron current density')
axis.legend()
axis.grid()
#plt.ylim(-1E-6,1E-6)
plt.show()

calc_recombination()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Recombination", fontsize=16)

axis.semilogy(1E6*parameters.pos_x,
              parameters.q*parameters.recombination*parameters.dx,
              label='Recombination')

axis.legend()
plt.show()

# %% [markdown]
# The following code ramps the recombination.

# %%
for i in np.linspace(1, 800, 10):

    print("i:",i)
    print ("parameters.Cau:",2.3E-13*1E-8*i)
    
    parameters.Cau = np.full(parameters.n, 2.3E-13*1E-8*i)

    
    # parameters.Cau = np.full(parameters.n, 2.3E-13*1E-8)


    solver.solve_bias(bias_point,0)   


    # Electron and hole current density 

    j_p =     hole_current_density()
    j_n = electron_current_density()

    fig, axis = plt.subplots(1,1, sharey=True)
    fig.suptitle("Current density of holes and electrons", fontsize=16)

    axis.plot(j_p, label='Hole current density')
    axis.plot(j_n, label='Electron current density')
    axis.legend()
    axis.grid()
    #plt.ylim(-1E-6,1E-6)
    plt.show()

calc_recombination()

fig, axis = plt.subplots(1,1, sharey=True)
fig.suptitle("Recombination", fontsize=16)

axis.semilogy(1E6*parameters.pos_x,
              parameters.q*parameters.recombination*parameters.dx,
              label='Recombination')

axis.legend()
plt.show()
# Out:
# i: 1.0
# parameters.Cau: 2.3e-21
# i: 89.77777777777777
# parameters.Cau: 2.0648888888888887e-19
# i: 178.55555555555554
# parameters.Cau: 4.1067777777777776e-19
# i: 267.3333333333333
# parameters.Cau: 6.148666666666666e-19
# i: 356.1111111111111
# parameters.Cau: 8.190555555555555e-19
# i: 444.88888888888886
# parameters.Cau: 1.0232444444444443e-18
# i: 533.6666666666666
# parameters.Cau: 1.2274333333333332e-18
# i: 622.4444444444443
# parameters.Cau: 1.431622222222222e-18
# i: 711.2222222222222
# parameters.Cau: 1.6358111111111109e-18
# i: 800.0
# parameters.Cau: 1.84e-18
